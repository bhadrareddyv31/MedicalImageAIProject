# %%
from keras.preprocessing import image
import numpy as np
from tensorflow.keras.models import load_model

# Load and preprocess the image
img = image.load_img(img_path, target_size=(224, 224))  # MobileNetV2 size
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0) / 255.0

# Load model
model = load_model('/content/drive/MyDrive/chest_xray_model.h5')  # or .keras if that's what you saved

# Predict
pred = model.predict(img_array)
print("📊 Raw Prediction:", pred)

# Interpret the prediction
if pred.shape[1] == 1:
    class_name = 'PNEUMONIA' if pred[0][0] > 0.5 else 'NORMAL'
else:
    class_names = ['NORMAL', 'PNEUMONIA']
    class_name = class_names[np.argmax(pred)]

print("✅ Predicted Class:", class_name)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 📊 Raw Prediction: [[0.08877737]]
# ✅ Predicted Class: NORMAL
